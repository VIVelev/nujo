# %%
import numpy as np

import torch as th
import nujo as nj

# %%
X = np.random.rand(3, 3)
y = np.random.rand(3, 1)

W1 = np.random.rand(3, 2)
W2 = np.random.rand(2, 1)

X_nj = nj.Tensor(X)
y_nj = nj.Tensor(y)
W1_nj = nj.Tensor(W1, diff=True, name='W1')
W2_nj = nj.Tensor(W2, diff=True, name='W2')

X_th = th.tensor(X)
y_th = th.tensor(y)
W1_th = th.tensor(W1, requires_grad=True)
W2_th = th.tensor(W2, requires_grad=True)

# %%
loss_nj = nj.sum()((X_nj @ W1_nj @ W2_nj - y_nj) ** 2)

# %%
loss_th = th.sum((X_th @ W1_th @ W2_th - y_th) ** 2)

# %%
loss_nj.backward(_debug=True)
loss_th.backward(th.ones_like(loss_th))
# Out:
# ==============================
# <Z<InnerSum>#24>
# --------------------------------
# [0.04230628]
#
# Shape: (1,)
# Has 0 dependencies:
# Grad Dependecies: []
#
#
# ==============================
# <Z<Pow>#20>
# --------------------------------
# [[0.0316574 ]
#  [0.00450894]
#  [0.00613994]]
#
# Shape: (3, 1)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<InnerSum>#24 [1]>, <weight[Z<InnerSum>#24]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<InnerSum>#24]>
# --------------------------------
# [1.]
# Shape: (1,)
#
# -----
# Z Weight: <weight[Z<InnerSum>#24]>
# --------------------------------
# [[1.]
#  [1.]
#  [1.]]
# Shape: (3, 1)
#
# ##########
# Current Grad: <grad[Z<Pow>#20]>
# --------------------------------
# [[1.]
#  [1.]
#  [1.]]
# Shape: (3, 1)
# -----
#
#
# ==============================
# <Z<Add>#15>
# --------------------------------
# [[0.17792528]
#  [0.06714861]
#  [0.07835776]]
#
# Shape: (3, 1)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<Pow>#20 [2]>, <weight[Z<Pow>#20]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<Pow>#20]>
# --------------------------------
# [[1.]
#  [1.]
#  [1.]]
# Shape: (3, 1)
#
# -----
# Z Weight: <weight[Z<Pow>#20]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
#
# ##########
# Current Grad: <grad[Z<Add>#15]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
# -----
#
#
# ==============================
# <Z<MatMul>#9>
# --------------------------------
# [[0.26825537]
#  [0.35785779]
#  [0.15480485]]
#
# Shape: (3, 1)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<Add>#15 [3]>, <weight[Z<Add>#15]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<Add>#15]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
#
# -----
# Z Weight: <weight[Z<Add>#15]>
# --------------------------------
# [[1.]
#  [1.]
#  [1.]]
# Shape: (3, 1)
#
# ##########
# Current Grad: <grad[Z<MatMul>#9]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
# -----
#
#
# ==============================
# <Z<MatMul>#5>
# --------------------------------
# [[1.12599545 0.98336028]
#  [0.98919603 1.38511075]
#  [0.59862982 0.57478799]]
#
# Shape: (3, 2)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<MatMul>#9 [5]>, <weight[Z<MatMul>#9]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<MatMul>#9]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
#
# -----
# Z Weight: <weight[Z<MatMul>#9]>
# --------------------------------
# [[0.03349892]
#  [0.2344367 ]]
# Shape: (2, 1)
#
# ##########
# Current Grad: <grad[Z<MatMul>#5]>
# --------------------------------
# [[0.01192061 0.08342443]
#  [0.00449881 0.0314842 ]
#  [0.0052498  0.03673987]]
# Shape: (3, 2)
# -----
#
#
# ==============================
# <W2>
# --------------------------------
# [[0.03349892]
#  [0.2344367 ]]
#
# Shape: (2, 1)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<MatMul>#9 [5]>, <weight[Z<MatMul>#9]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<MatMul>#9]>
# --------------------------------
# [[0.35585055]
#  [0.13429722]
#  [0.15671552]]
# Shape: (3, 1)
#
# -----
# Z Weight: <weight[Z<MatMul>#9]>
# --------------------------------
# [[1.12599545 0.98336028]
#  [0.98919603 1.38511075]
#  [0.59862982 0.57478799]]
# Shape: (3, 2)
#
# ##########
# Current Grad: <grad[W2]>
# --------------------------------
# [[0.62734696]
#  [0.62602402]]
# Shape: (2, 1)
# -----
#
#
# ==============================
# <W1>
# --------------------------------
# [[0.8014007  0.34134339]
#  [0.45621898 0.68668777]
#  [0.48168968 0.85831985]]
#
# Shape: (3, 2)
# Has 1 dependencies:
# Grad Dependecies: [(<Z<MatMul>#5 [7]>, <weight[Z<MatMul>#5]>)]
#
# ~~~~~~~~~~
# Z Grad: <grad[Z<MatMul>#5]>
# --------------------------------
# [[0.01192061 0.08342443]
#  [0.00449881 0.0314842 ]
#  [0.0052498  0.03673987]]
# Shape: (3, 2)
#
# -----
# Z Weight: <weight[Z<MatMul>#5]>
# --------------------------------
# [[0.8840931  0.49370879 0.39910199]
#  [0.26157242 0.73894831 0.91853633]
#  [0.41083996 0.3600932  0.21819242]]
# Shape: (3, 3)
#
# ##########
# Current Grad: <grad[W1]>
# --------------------------------
# [[0.01387252 0.09708456]
#  [0.01110012 0.07768234]
#  [0.01003533 0.07023059]]
# Shape: (3, 2)
# -----

# %%
print(loss_nj.value - loss_th.detach().numpy())
# Out:
# [0.]

# %%
print(np.abs(W1_nj.grad.value - W1_th.grad.detach().numpy()))
# Out:
# [[0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.38777878e-17]
#  [0.00000000e+00 0.00000000e+00]]

# %%
print(np.abs(W2_nj.grad.value - W2_th.grad.detach().numpy()))
# Out:
# [[1.11022302e-16]
#  [1.11022302e-16]]
